# %% [markdown]
# # Titanic Survival Analysis
#
# ## Исследование данных о пассажирах Титаника и изучение взаимодействия факторов, которые могли повлиять на их выживаемость

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Titanic Survival Analysis
#
# ## Шаг 1. Загрузка и первичный осмотр данных
#
# Цель: понять структуру датасета, типы данных и качество данных перед началом анализа.

# %%
df = pd.read_csv(r"../data/Titanic-Dataset.csv")
print(df.head(2))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.shape
# Out:
# (891, 12)

# %%
print(df[["Name", "Age"]].tail(2))
df["Age"].dtype
# Out:
#                       Name   Age
# 889  Behr, Mr. Karl Howell  26.0
# 890    Dooley, Mr. Patrick  32.0
# dtype('float64')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isna().sum(axis=1).sort_values(ascending=False)
# Out:
# 5      2
# 19     2
# 17     2
# 674    2
# 32     2
#       ..
# 867    0
# 887    0
# 3      0
# 889    0
# 1      0
# Length: 891, dtype: int64

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
float(df["Age"].mean())
# Out:
# 29.69911764705882

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df[df["Age"] < 18].value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                                                Sex     Age    SibSp  Parch  Ticket    Fare      Cabin    Embarked
# 11           1         3       Sandstrom, Miss. Marguerite Rut                                                     female  4.00   1      1      PP 9549   16.7000   G6       S           1
# 184          1         2       Becker, Master. Richard F                                                           male    1.00   2      1      230136    39.0000   F4       S           1
# 194          1         2       Navratil, Master. Michel M                                                          male    3.00   1      1      230080    26.0000   F2       S           1
# 206          0         3       Strom, Miss. Telma Matilda                                                          female  2.00   0      1      347054    10.4625   G6       S           1
# ...
